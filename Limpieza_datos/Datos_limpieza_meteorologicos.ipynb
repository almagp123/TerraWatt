# %%
import os
import pandas as pd

# %% [markdown]
# Vamos a empezar eliminando las columnas de nombre e indicativo, ya que hacen referencia a la informacion de la estacion meteorologica ya que como vamos a agruparlos por provinias no es relevante.
#
# Por otro lado, en los siguientes apartados comprobamos que los archivos son los mismos en ambas carpetas, tanto en la d elos datos brutos como en los datos limpios, para verificar que no haya ningun error.
#
# En primera instancia, obtenemos que no tineen el mismo número de archivos, ya que en el archivo indicado en el código siguiente tiene una errata en una de las líneas, por lo que la eliminamos y volvemos a procesar todo para verificar que ahora tenemos el mismo número de archivos.

# %% [markdown]
# **Estas son las conclusiones que sacamos cuando nos dimos cuenta que este archivo era problemático**
#
# Como podemos ver el error es en el archivo 1111X-20120301-20241103.csv, por lo que vamos a proceser a analizarlo.
#
# Vemos que el error se encuentra en la linea 4474 ya que se muetsra de la siguiente manera:
#
# 2024-05-29;1111X;SANTANDER;CANTABRIA;51;16.0;4.6;13.7;05:002024-05-03;1111X;SANTANDER;CANTABRIA;51;14.1;Ip;9.7;05:20;18.5;23:59;07;5.0;11.7;16:20;8.5;1011.2;08;1004.1;24
#
#
# Como podemos ver es una errata, por lo que primeramente eliminaremos esta fila y actoseguido realizaremos el proceso de nuevo. Volveremos a ejecutar todo de nuevo comprobando otra vez que el número de archivos esta ves si es igual.

# %%
# Definimos de donde vamos a obtener los datos y donde vamos a guardar los datos limpios 
input_folder = "Datos_brutos_meteorologicos"  
output_folder = "Datos_limpios_meteorologicos"  

# Crear la carpeta de salida si no existe
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Procesar cada archivo CSV en la carpeta de entrada
for file_name in os.listdir(input_folder):
    if file_name.endswith(".csv"):  # Verificar que sea un archivo CSV
        input_path = os.path.join(input_folder, file_name)

        try:
            # Eliminamos una linea de este archivo ya que hay una errata y no nos permite limpar bien el 
            # documento (la comprobación esta en el siguiente apartado)
            if file_name == "1111X-20120301-20241103.csv":
                # Leer todas las líneas del archivo
                with open(input_path, 'r', encoding='latin1') as file:
                    lines = file.readlines()
                # Eliminar la línea problemática 
                problematic_line_index = 4473  
                if len(lines) > problematic_line_index:
                    del lines[problematic_line_index]
                    print(f"Línea problemática eliminada en el archivo {file_name}")
                else:
                    print(f"El archivo {file_name} tiene menos de {problematic_line_index + 1} líneas.")
                # Escribir las líneas corregidas a un archivo temporal
                temp_input_path = os.path.join(input_folder, 'temp_' + file_name)
                with open(temp_input_path, 'w', encoding='latin1') as file:
                    file.writelines(lines)
                # Leer el archivo temporal con pandas
                df = pd.read_csv(temp_input_path, delimiter=';', encoding='latin1', engine='python')
                # Eliminar el archivo temporal
                os.remove(temp_input_path)
            else:
                
                df = pd.read_csv(input_path, delimiter=';', encoding='latin1', engine='python')
            
            df.columns = df.columns.str.strip()  # Quitar espacios en los nombres de columnas
            
            # Eliminar las columnas 'INDICATIVO' y 'NOMBRE', si existen
            columns_to_drop = [col for col in ['INDICATIVO', 'NOMBRE'] if col in df.columns]
            df = df.drop(columns=columns_to_drop)
            
            # Guardar el archivo  en la carpeta de salida
            output_path = os.path.join(output_folder, file_name)
            df.to_csv(output_path, sep=';', index=False, encoding='latin1')
        
        except Exception as e:
            print(f"Error procesando el archivo {input_path}: {e}")

print("Procesamiento completado.")
# Out:
# Línea problemática eliminada en el archivo 1111X-20120301-20241103.csv
# Procesamiento completado.

# %% [markdown]
# Comprobamos que los tenemos el mismo número de archivos en ambas carpetas para verificar que el proceso se ha realizado correctamente. Si existe algún problema, nos dirá el nombre de los archivos faltante o extras en ambas carpetas.

# %%
# Definimos las carpetas
input_folder = "Datos_brutos_meteorologicos"  
output_folder = "Datos_limpios_meteorologicos" 

# Obtener listas de archivos en ambas carpetas
input_files = set(os.listdir(input_folder))
output_files = set(os.listdir(output_folder))

# Contar archivos en cada carpeta
num_input_files = len(input_files)
num_output_files = len(output_files)

# Mostrar el número de archivos en cada carpeta
print(f"Número de archivos en '{input_folder}': {num_input_files}")
print(f"Número de archivos en '{output_folder}': {num_output_files}")

# Comparar los archivos
missing_files = input_files - output_files

# Mostrar los archivos que faltan en la carpeta NUEVO
if len(missing_files) == 0 and num_input_files == num_output_files:
    print("Todas las carpetas tienen los mismos archivos con el mismo nombre.")
else:
    print(f"Hay {len(missing_files)} archivos que faltan en la carpeta '{output_folder}':")
    for file_name in missing_files:
        print(file_name)
# Out:
# Número de archivos en 'Datos_brutos_meteorologicos': 944
# Número de archivos en 'Datos_limpios_meteorologicos': 944
# Todas las carpetas tienen los mismos archivos con el mismo nombre.

# %% [markdown]
# Vamos a proceder a obtener el nombre de las provincias, por si alguna duplicada o con acrónimos diferentes, por ejemplo Comunidad y C. para no tener archivos duplicados cuando los unamos en base a las provincias.

# %%
# Definir la carpeta de entrada
input_folder = "Datos_limpios_meteorologicos"

provincias_unicas = set()

# Procesar cada archivo CSV en la carpeta
for file_name in os.listdir(input_folder):
    if file_name.endswith(".csv"):  
        input_path = os.path.join(input_folder, file_name)
        
        try:
            df = pd.read_csv(input_path, delimiter=';', encoding='latin1', engine='python')
            
            # Verificar si existe la columna "PROVINCIA"
            if "PROVINCIA" in df.columns:
                # Agregar las provincias únicas al conjunto
                provincias_unicas.update(df["PROVINCIA"].dropna().unique())
            else:
                print(f"El archivo {file_name} no contiene la columna 'PROVINCIA'")
        
        except Exception as e:
            print(f"Error procesando el archivo {file_name}: {e}")

# Mostrar las provincias únicas
print("\nProvincias únicas encontradas:")
for provincia in sorted(provincias_unicas):
    print(provincia)
# Out:
# Provincias únicas encontradas:
# A CORUÑA
# ALBACETE
# ALICANTE
# ALMERIA
# ARABA/ALAVA
# ASTURIAS
# AVILA
# BADAJOZ
# BALEARES
# BARCELONA
# BIZKAIA
# BURGOS
# CACERES
# CADIZ
# CANTABRIA
# CASTELLON
# CEUTA
# CIUDAD REAL
# CORDOBA
# CUENCA
# GIPUZKOA
# GIRONA
# GRANADA
# GUADALAJARA
# HUELVA
# HUESCA
# ILLES BALEARS
# JAEN
# LA RIOJA
# LAS PALMAS
# LEON
# LLEIDA
# LUGO
# MADRID
# MALAGA
# MELILLA
# MURCIA
# NAVARRA
# OURENSE
# PALENCIA
# PONTEVEDRA
# SALAMANCA
# SANTA CRUZ DE TENERIFE
# SEGOVIA
# SEVILLA
# SORIA
# STA. CRUZ DE TENERIFE
# TARRAGONA
# TERUEL
# TOLEDO
# VALENCIA
# VALLADOLID
# ZAMORA
# ZARAGOZA

# %% [markdown]
# Como podemos ver en este caso obtenemos dos Santa cruz de tenerife ya que en una de ellas se usa el acronimo sta. y por otro lado vemos que la provincia de alava esta etiquetada como Araba/alava Por lo que vamos a actualizarlo

# %% [markdown]
# Por otro lado, como tenemos datos que son dese 1980 vamos a eliminar todos los datos anteriores a 2014, ya que los datos con los que contamos del precio de la elictricidad no son más antiguos de eso.

# %%
# Definir las carpetas de entrada y salida
folder = "Datos_limpios_meteorologicos"
# Crear la carpeta de salida si no existe
if not os.path.exists(folder):
    os.makedirs(folder)

# Recorrer todos los archivos en la carpeta de entrada
for file_name in os.listdir(folder):
    if file_name.endswith(".csv"):  # Verificar que sea un archivo CSV
        input_path = os.path.join(folder, file_name)

        try:
            # Leer el archivo CSV
            df = pd.read_csv(input_path, delimiter=';', encoding='latin1', engine='python')

            # Reemplazar valores incorrectos en la columna "PROVINCIA"
            if "PROVINCIA" in df.columns:
                df["PROVINCIA"] = df["PROVINCIA"].replace({
                    "ARABA/ALAVA": "ALAVA",
                    "STA. CRUZ DE TENERIFE": "SANTA CRUZ DE TENERIFE",
                    "BALEARES": "ILLES BALEARS"
                })

            # Verificar que la columna FECHA existe
            if "FECHA" in df.columns:
                # Convertir la columna FECHA a formato datetime para filtrado
                df["FECHA"] = pd.to_datetime(df["FECHA"], format="%Y-%m-%d", errors="coerce")

                # Filtrar las filas con fechas posteriores al 1 de abril de 2014
                df = df[df["FECHA"] >= "2014-04-01"]

            # Guardar el archivo procesado
            output_path = os.path.join(folder, file_name)
            df.to_csv(output_path, sep=';', index=False, encoding="latin1")

        except Exception as e:
            print(f"Error procesando el archivo {input_path}: {e}")

print("Procesamiento completado.")
# Out:
# Procesamiento completado.

# %% [markdown]
# Vamos a simplificar los datos por provincia y por fecha, haciendo la media de los valores en función de la provincia, es decir si contamos con 10 estaciones meteorologicas en Guadalajara, se hará la media diaria de todos los valores que existen dentro de esta provincia, siempre segmentados por días.
#
# Además sustituimos todos estos datasets y los sustituimos por uno independiente por cada provincia, el nombre de cada archivo será el correspondiente a cada provincia.

# %%
folder = "Datos_limpios_meteorologicos"

if not os.path.exists(folder):
    os.makedirs(folder)

# Crear un diccionario para almacenar los DataFrames por provincia
dataframes_by_province = {}
generated_files = []  # Lista para almacenar los nombres de los archivos consolidados

# Leer todos los archivos y agruparlos por provincia
for file_name in os.listdir(folder):
    if file_name.endswith(".csv"):  # Verificar que sea un archivo CSV
        input_path = os.path.join(folder, file_name)
        try:
            # Leer el archivo CSV
            df = pd.read_csv(input_path, delimiter=';', encoding='latin1', engine='python')
            
            # Asegurar que las columnas necesarias existen
            if {"PROVINCIA", "FECHA"}.issubset(df.columns):
                # Convertir la columna FECHA a formato datetime para agrupar
                df["FECHA"] = pd.to_datetime(df["FECHA"], format="%Y-%m-%d", errors="coerce")
                
                # Agregar los datos al diccionario por provincia
                for provincia in df["PROVINCIA"].unique():
                    if provincia not in dataframes_by_province:
                        dataframes_by_province[provincia] = []
                    dataframes_by_province[provincia].append(df[df["PROVINCIA"] == provincia])
            else:
                print(f"El archivo {file_name} no tiene las columnas necesarias.")
        
        except Exception as e:
            print(f"Error leyendo archivo {file_name}: {e}")

# Procesar los datos de cada provincia
for provincia, dfs in dataframes_by_province.items():
    print(f"Procesando provincia: {provincia}")

    try:
        # Combinar todos los DataFrames de la provincia
        combined_df = pd.concat(dfs, ignore_index=True)
        
        # Agrupar por fecha y calcular la media de las columnas numéricas
        aggregated_df = combined_df.groupby("FECHA").mean(numeric_only=True).reset_index()
        
        # Guardar el archivo consolidado para la provincia
        output_file_name = f"{provincia.replace('/', '_')}.csv"
        output_path = os.path.join(folder, output_file_name)  # Reemplazar '/' por '_' en nombres de archivos
        aggregated_df.to_csv(output_path, sep=';', index=False, encoding='latin1')
        print(f"Archivo consolidado guardado: {output_path}")
        
        # Registrar el archivo generado
        generated_files.append(output_file_name)
    
    except Exception as e:
        print(f"Error procesando la provincia {provincia}: {e}")

# Eliminar los archivos originales que no están en la lista de archivos generados
for file_name in os.listdir(folder):
    if file_name not in generated_files and file_name.endswith(".csv"):
        file_path = os.path.join(folder, file_name)
        os.remove(file_path)
        print(f"Archivo eliminado: {file_path}")

print("Consolidación y limpieza completadas.")
# Out:
# Procesando provincia: TARRAGONA
# Archivo consolidado guardado: Datos_limpios_meteorologicos\TARRAGONA.csv
# Procesando provincia: BARCELONA
# Archivo consolidado guardado: Datos_limpios_meteorologicos\BARCELONA.csv
# Procesando provincia: GIRONA
# Archivo consolidado guardado: Datos_limpios_meteorologicos\GIRONA.csv
# Procesando provincia: NAVARRA
# Archivo consolidado guardado: Datos_limpios_meteorologicos\NAVARRA.csv
# Procesando provincia: GIPUZKOA
# Archivo consolidado guardado: Datos_limpios_meteorologicos\GIPUZKOA.csv
# Procesando provincia: ALAVA
# Archivo consolidado guardado: Datos_limpios_meteorologicos\ALAVA.csv
# Procesando provincia: BIZKAIA
# Archivo consolidado guardado: Datos_limpios_meteorologicos\BIZKAIA.csv
# Procesando provincia: CANTABRIA
# Archivo consolidado guardado: Datos_limpios_meteorologicos\CANTABRIA.csv
# Procesando provincia: ASTURIAS
# Archivo consolidado guardado: Datos_limpios_meteorologicos\ASTURIAS.csv
# Procesando provincia: LEON
# Archivo consolidado guardado: Datos_limpios_meteorologicos\LEON.csv
# Procesando provincia: LUGO
# Archivo consolidado guardado: Datos_limpios_meteorologicos\LUGO.csv
# Procesando provincia: A CORUÑA
# Archivo consolidado guardado: Datos_limpios_meteorologicos\A CORUÑA.csv
# Procesando provincia: PONTEVEDRA
# Archivo consolidado guardado: Datos_limpios_meteorologicos\PONTEVEDRA.csv
# Procesando provincia: OURENSE
# Archivo consolidado guardado: Datos_limpios_meteorologicos\OURENSE.csv
# Procesando provincia: SORIA
# Archivo consolidado guardado: Datos_limpios_meteorologicos\SORIA.csv
# Procesando provincia: BURGOS
# Archivo consolidado guardado: Datos_limpios_meteorologicos\BURGOS.csv
# Procesando provincia: SEGOVIA
# Archivo consolidado guardado: Datos_limpios_meteorologicos\SEGOVIA.csv
# Procesando provincia: VALLADOLID
# Archivo consolidado guardado: Datos_limpios_meteorologicos\VALLADOLID.csv
# Procesando provincia: PALENCIA
# Archivo consolidado guardado: Datos_limpios_meteorologicos\PALENCIA.csv
# Procesando provincia: AVILA
# Archivo consolidado guardado: Datos_limpios_meteorologicos\AVILA.csv
# Procesando provincia: MADRID
# Archivo consolidado guardado: Datos_limpios_meteorologicos\MADRID.csv
# Procesando provincia: SALAMANCA
# Archivo consolidado guardado: Datos_limpios_meteorologicos\SALAMANCA.csv
# Procesando provincia: ZAMORA
# Archivo consolidado guardado: Datos_limpios_meteorologicos\ZAMORA.csv
# Procesando provincia: GUADALAJARA
# Archivo consolidado guardado: Datos_limpios_meteorologicos\GUADALAJARA.csv
# Procesando provincia: CUENCA
# Archivo consolidado guardado: Datos_limpios_meteorologicos\CUENCA.csv
# Procesando provincia: TOLEDO
# Archivo consolidado guardado: Datos_limpios_meteorologicos\TOLEDO.csv
# Procesando provincia: CACERES
# Archivo consolidado guardado: Datos_limpios_meteorologicos\CACERES.csv
# Procesando provincia: ALBACETE
# Archivo consolidado guardado: Datos_limpios_meteorologicos\ALBACETE.csv
# Procesando provincia: CIUDAD REAL
# Archivo consolidado guardado: Datos_limpios_meteorologicos\
-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B236C-20081101-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B248-19710401-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B275E-20210710-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B278-19720801-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B301-20081101-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B334X-20050401-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B341X-20220726-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B346X-19890209-20220725.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B362X-20040301-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B373X-20081022-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B398A-20110530-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B410B-20150510-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B434X-19930101-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B496X-20081024-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B526X-20040201-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B569X-19890101-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B603X-20060315-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B605X-20050412-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B614E-20081101-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B640X-20210213-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B644B-20081101-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B656A-20150501-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B662X-20081101-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B684A-20081101-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B691-19810701-20240930.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B691Y-20110419-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B760X-20090318-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B780X-19890207-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B800X-20100101-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B825B-20081111-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B860X-20040601-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B870C-20150710-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B893-19650101-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B908X-20050501-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B925-20180720-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B954-19440101-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B957-20150603-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\B986-20150603-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C018J-19880901-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C019V-19920101-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C029O-19721101-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C038N-20081128-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C048W-20081128-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C101A-20191112-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C117A-19341001-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C117Z-20090512-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C126A-19711101-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C129V-20100223-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C129Z-20000122-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C139E-19700401-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C148F-20090514-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C229J-19930201-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C239N-20081126-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C248E-19610901-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C249I-19670101-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C258K-19610901-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C314Z-20090709-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C316I-20180807-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C317B-19850401-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C319W-20090709-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C328W-20090708-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C329B-20011201-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C329Z-19950101-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C406G-19830301-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C412N-20140501-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C415A-20140501-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C417J-20140501-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C418I-20140501-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C418L-20140501-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C419L-20180719-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C419X-19750101-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C422A-20140501-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C423R-20140501-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C426E-20140501-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C426I-20140501-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C426R-20140507-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C428T-20090508-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C428U-20140501-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C429I-19800701-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C430E-19200101-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C436I-20140501-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C436L-20140501-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C437E-20140501-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C438N-20090506-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C439J-20140101-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C446G-20090711-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C447A-19410801-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C448C-20140501-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C449C-19310101-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C449F-20090506-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C449Q-20140501-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C453I-20140501-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C455M-20140501-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C456E-20140501-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C456P-20140501-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C456R-20140501-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C457E-20140501-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C457I-20090506-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C458A-19620401-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C458U-20140501-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C459Z-19960612-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C466O-20140501-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C467I-20140501-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C468I-20140501-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C468O-20140501-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C468X-20191110-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C611E-19680101-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C612F-19910101-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C614H-20170427-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C619I-20000114-20160915.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C619X-20081115-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C619Y-20100628-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C623I-19520201-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C625O-19650101-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C628B-20081120-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C629Q-19920201-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C629X-20030207-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C635B-20090717-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C639M-19940601-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C639U-19920501-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C648C-20081113-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C648N-19940101-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C649I-19510101-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C649R-20090718-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C656V-19881101-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C658L-19930101-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C658X-20081119-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C659H-20020501-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C659M-20130921-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C665T-20081115-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C668V-19890301-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C669B-19890501-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C689E-19940701-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C839I-19920101-20161106.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C839X-20100628-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C916Q-20090715-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C917E-19830701-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C919K-20091201-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C925F-20090713-20241103.csv
# Archivo eliminado: Datos_limpios_meteorologicos\C939T-20090714-20241103.csv
# Consolidación y limpieza completadas.

# %% [markdown]
# Por otro lado, nos vemos obligados a eliminar las ciudades de Ceuta y Melilla, ya que los datos que nos han proporcionado sobre el consumo no cuentan con datos de estas cuidades autónomas.

# %%
folder_path = "Datos_limpios_meteorologicos"

# Archivos a eliminar
archivos_a_eliminar = ["CEUTA.csv", "MELILLA.csv"]

# Recorrer los archivos en la carpeta y eliminar los especificados
for archivo in archivos_a_eliminar:
    archivo_path = os.path.join(folder_path, archivo)
    if os.path.exists(archivo_path):
        os.remove(archivo_path)
        print(f"Archivo eliminado: {archivo_path}")
    else:
        print(f"Archivo no encontrado: {archivo_path}")

print("Proceso de eliminación completado.")
# Out:
# Archivo eliminado: Datos_limpios_meteorologicos\CEUTA.csv
# Archivo eliminado: Datos_limpios_meteorologicos\MELILLA.csv
# Proceso de eliminación completado.
